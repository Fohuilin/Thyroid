# %%
import simpleNomo
import pandas as pd

path = r"E:\Pystudy\Thyroid_P_N\data\ML\NPM\Nomogram\Logistic\Nomo_data\model_MRI.xlsx"

pd.read_excel(path)
# Out:
#             feature      coef    min    max        type  position
# 0         intercept -10.70630    NaN    NaN         NaN       NaN
# 1         threshold   0.34800    NaN    NaN         NaN       NaN
# 2          Quantity  -3.41341  0.000  1.000     nominal       NaN
# 3               ETE   2.48023  0.000  1.000     nominal       NaN
# 4         ADClesion   5.88315  0.474  1.342  continuous       NaN
# 5  ADCnormal-tissue   9.28603  0.600  1.299  continuous       NaN

# %%
nomo = simpleNomo.nomogram(path=path)
# Out:
# findfont: Font family 'Songti Sc' not found.
# findfont: Font family 'Songti Sc' not found.
# findfont: Font family 'Songti Sc' not found.
# findfont: Font family 'Songti Sc' not found.
# findfont: Font family 'Songti Sc' not found.
# findfont: Font family 'Songti Sc' not found.
# findfont: Font family 'Songti Sc' not found.
# findfont: Font family 'Songti Sc' not found.
# findfont: Font family 'Songti Sc' not found.
# findfont: Font family 'Songti Sc' not found.
# findfont: Font family 'Songti Sc' not found.
# findfont: Font family 'Songti Sc' not found.
# findfont: Font family 'Songti Sc' not found.
# findfont: Font family 'Songti Sc' not found.
# findfont: Font family 'Songti Sc' not found.
# findfont: Font family 'Songti Sc' not found.
# findfont: Font family 'Songti Sc' not found.
# findfont: Font family 'Songti Sc' not found.
# findfont: Font family 'Songti Sc' not found.
# findfont: Font family 'Songti Sc' not found.
# findfont: Font family 'Songti Sc' not found.
# ...
